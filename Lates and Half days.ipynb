# %%
import pandas as pd

# %%
df = pd.read_excel('Individual Details July-2023.xlsx')

# %%
df
# Out:
#                     Date        Name Late Time In Time Out   Status  \
# 0    2023-06-26 14:26:20  Aamir Raza    N   09:38    18:02  PRESENT
# 1    2023-06-27 11:34:04  Aamir Raza    N   09:34    18:50  PRESENT
# 2    2023-06-28 16:05:13  Aamir Raza    N   09:42    18:34  PRESENT
# 3    2023-07-03 15:24:48  Aamir Raza    N   09:44    18:09  PRESENT
# 4    2023-07-04 14:43:21  Aamir Raza    N   09:40    18:19  PRESENT
# ...                  ...         ...  ...     ...      ...      ...
# 2969 2023-07-13 09:44:35  Kashif Ali    N   09:44    09:44  PRESENT
# 2970 2023-07-14 09:44:32  Kashif Ali    N   09:44    18:03  PRESENT
# 2971 2023-07-15 09:35:18  Kashif Ali    N   09:35    09:41  PRESENT
# 2972 2023-07-17 09:41:43  Kashif Ali    N   09:41    09:43  PRESENT
# 2973 2023-07-18 09:43:26  Kashif Ali    N   09:43    09:35  PRESENT
#
#      Unnamed: 6 Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10 Unnamed: 11  \
# ...

# %%
df = df.drop(df.iloc[:,range(6,14)],axis=1)

# %%
df.loc[:,'Date'] = pd.to_datetime(pd.to_datetime(df.loc[:,'Date']).dt.strftime('%Y-%m-%d'))
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_8224\1751002683.py:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:,'Date'] = pd.to_datetime(pd.to_datetime(df.loc[:,'Date']).dt.strftime('%Y-%m-%d'))

# %%
pattern = '%H:%M'
df['Time In'] = pd.to_datetime(df['Time In'],format=pattern)

# %%
late = df.loc[(df['Time In'] >  '1900-01-01 09:45:00') & (df['Time In'] < '1900-01-01 10:30:00')]

# %%
half_days = df.loc[(df['Time In'] >  '1900-01-01 10:30:00')]

# %%
late_1 = late.loc[:,['Date','Name','Time In']]

# %%
late_1['Time In'] = late_1['Time In'].dt.strftime('%H:%M')

# %%
late_1
# Out:
#            Date                          Name Time In
# 13   2023-07-14                    Aamir Raza   09:50
# 28   2023-07-06               Aashir Sarfaraz   09:55
# 69   2023-06-26          Abdul Mughees Shoaib   09:46
# 98   2023-07-10                   Abu Huraira   10:00
# 117  2023-07-05               Ahmed-din-azhar   09:52
# 120  2023-07-08               Ahmed-din-azhar   09:47
# 122  2023-07-11               Ahmed-din-azhar   09:46
# 125  2023-07-14               Ahmed-din-azhar   09:50
# 127  2023-07-17               Ahmed-din-azhar   09:49
# 130  2023-07-20               Ahmed-din-azhar   09:46
# 132  2023-07-22               Ahmed-din-azhar   10:23
# 133  2023-07-24               Ahmed-din-azhar   09:47
# 143  2023-07-10                  Ahmer Kamran   10:22
# 186  2023-07-05                    Ameer khan   09:46
# 206  2023-06-28           Anjum Rafique Malik   09:54
# 211  2023-07-07           Anjum Rafique Malik   09:52
# ...

# %%
half_days_1 = half_days.loc[:,['Date','Name','Time In']]
half_days_1['Time In'] = half_days_1['Time In'].dt.strftime('%H:%M')

# %%
half_days_1
# Out:
#            Date                          Name Time In
# 37   2023-07-17               Aashir Sarfaraz   10:47
# 43   2023-07-24               Aashir Sarfaraz   18:26
# 54   2023-07-09                  Abdul hammad   11:30
# 88   2023-07-25          Abdul Mughees Shoaib   12:37
# 147  2023-07-14                  Ahmer Kamran   10:37
# 148  2023-07-15                  Ahmer Kamran   21:42
# 154  2023-07-22                  Ahmer Kamran   21:36
# 166  2023-07-09                    ALI HAIDER   21:04
# 184  2023-07-03                    Ameer khan   10:42
# 238  2023-07-13          Aqib Majeed (Sukker)   10:49
# 242  2023-07-18          Aqib Majeed (Sukker)   10:52
# 277  2023-07-05              Arsalan siddiqui   11:09
# 313  2023-07-24              Arshad Ali Kazmi   11:05
# 319  2023-07-05                        Asghar   10:44
# 337  2023-06-26                Atiq ur rehman   11:22
# 374  2023-07-17                    awais khan   18:48
# ...

# %%
late_1.to_excel('Lates.xlsx', index=None)

# %%
half_days_1.to_excel('Half Days.xlsx', index=None)
